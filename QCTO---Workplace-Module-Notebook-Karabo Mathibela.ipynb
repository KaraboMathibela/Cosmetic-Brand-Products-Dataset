# %% [markdown]
# # QCTO - Workplace Module
#
# ### Project Title: Cosmetic Brand Products Dataset.
# #### Done By: Karabo Mathibela
#
# ![Different Brands:](brands.jpg)
#
# © ExploreAI 2024
#
# ---
#
# ## Table of Contents
#
# <a href=#BC> Background Context</a>
#
# <a href=#one>1. Importing Packages</a>
#
# <a href=#two>2. Data Collection and Description</a>
#
# <a href=#three>3. Loading Data </a>
#
# <a href=#four>4. Data Cleaning and Filtering</a>
#
# <a href=#five>5. Exploratory Data Analysis (EDA)</a>
#
# <a href=#six>6. Modeling </a>
#
# <a href=#seven>7. Evaluation and Validation</a>
#
# <a href=#eight>8. Final Model</a>
#
# <a href=#nine>9. Conclusion and Future Work</a>
#
# <a href=#ten>10. References</a>

# %% [markdown]
# ---
#  <a id="BC"></a>
# ## **Background Context**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** The makeup_data file provides comprehensive details about cosmetic products, featuring information on brands, product names, prices, descriptions, and various other attributes. This dataset serves as a valuable asset for analyzing the cosmetics industry, conducting market research, and gaining insights into product categories, pricing patterns, and more.

# %% [markdown]
# ---
# <a href=#one></a>
# ## **Importing Packages**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Set up the Python environment with necessary libraries and tools.
# * **Details:** List and import all the Python packages that will be used throughout the project such as Pandas for data manipulation, Matplotlib/Seaborn for visualization, scikit-learn for modeling, etc.
# ---

# %%
#Please use code cells to code in and do not forget to comment your code.
# Import necessary packages and unzip the uploaded file
import zipfile
import os

# Use a raw string for the path
zip_file_path = r'C:\Users\karab\Downloads\makeup_data.json.zip'
extracted_folder_path = r'C:\Users\karab\Downloads\makeup_data'

# Check if the zip file exists
if os.path.exists(zip_file_path):
    # Unzipping the file
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extracted_folder_path)
else:
    print(f"File not found: {zip_file_path}")

# %% [markdown]
# ---
# <a href=#two></a>
# ## **Data Collection and Description**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Describe how the data was collected and provide an overview of its characteristics.
# * **Details:** Mention sources of the data, the methods used for collection (e.g., APIs, web scraping, datasets from repositories), and a general description of the dataset including size, scope, and types of data available (e.g., numerical, categorical).
# ---

# %%
#Please use code cells to code in and do not forget to comment your code. 
## Data Collection And Description
 * Purpose:
The dataset provides a mix of structured (numerical and categorical) and unstructured (textual) data, allowing for diverse analysis and research purposes.
Types of Data:

Numerical Data: Pricing information, product ratings, and quantities (e.g., volume or weight of the products).
Categorical Data: Brands, product names, categories (e.g., foundation, lipstick), ingredients, and other descriptive attributes.
Textual Data: Descriptions of the products, which may include marketing details, usage instructions, or unique selling points.
Other Attributes: Additional product characteristics such as colors (for makeup), finishes (matte, gloss), or skin types (for skincare)
    It is a open data source.
# Out:
#   Cell In[71], line 3
#     * Purpose:
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ---
# <a href=#three></a>
# ## **Loading Data**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Load the data into the notebook for manipulation and analysis.
# * **Details:** Show the code used to load the data and display the first few rows to give a sense of what the raw data looks like.
# ---

# %%
#Please use code cells to code in and do not forget to comment your code.
# ID: Unique identifier for the product (id: 1048).
# Brand: Name of the brand (brand: "colourpop").
product = {
    'id': 1048,
    'name': 'Product Name',
    'brand': 'colourpop',  # Product brand
    'price': 29.99
}

# Print product information
print(product)
# Out:
# {'id': 1048, 'name': 'Product Name', 'brand': 'colourpop', 'price': 29.99}

# %% [markdown]
# ---
# <a href=#four></a>
# ## **Data Cleaning and Filtering**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Prepare the data for analysis by cleaning and filtering.
# * **Details:** Include steps for handling missing values, removing outliers, correcting errors, and possibly reducing the data (filtering based on certain criteria or features).
# ---

# %%
#Please use code cells to code in and do not forget to comment your code.
# The dataset contains the following columns:

# Example of printing the columns of the dataframe
print(makeup_df.columns)

# id: Unique product ID
# brand: Brand name
# name: Product name
price_sign = "Currency symbol (e.g., $, €, etc.)"

# currency: Currency code (e.g., USD, CAD)
image_link = "C:/Users/karab/Downloads/cosmetics.jpg"
# product_link: URL to the product page
product_url = "https://www.bing.com/ck/a?!&&p=4f5748ebcd9442a7dd318b0c62b9ba984fdea3c841a239b61248fdbe81497f88JmltdHM9MTcyOTIwOTYwMA&ptn=3&ver=2&hsh=4&fclid=0d7d3078-3f95-6a36-03ca-24723e956bbd&psq=sephora&u=a1aHR0cHM6Ly93d3cuc2VwaG9yYS5jb20vP21zb2NraWQ9MGQ3ZDMwNzgzZjk1NmEzNjAzY2EyNDcyM2U5NTZiYmQ&ntb=1"
# description: Product description
# rating: Product rating (if available)
# category: Product category (e.g., pencil, liquid)
#product_type: General product classification (e.g., lip_liner, lipstick)
#tag_list: Tags like cruelty-free, vegan, etc.
#created_at: Product creation date
#updated_at: Last update date
#product_api_url: API link for the product
#api_featured_image: URL for the featured image of the product
#product_colors: A list of colors associated with the product
#Steps for Data Cleaning and Filtering:
# Handle Missing Values: We will check for missing values and decide how to handle them (e.g., removing rows or imputing values).

# Let's start by inspecting the missing values and handling them

# Importing necessary libraries for data manipulation
import pandas as pd
import zipfile
import os

# Path to the ZIP file
zip_file_path = r'C:\Users\karab\Downloads\makeup_data.json.zip'

# Extract the ZIP file to a temporary directory
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(r'C:\Users\karab\Downloads\makeup_data')

# Assuming the extracted JSON file is named 'makeup_data.json'
# Update this to the correct filename if necessary
makeup_df = pd.read_json(r'C:\Users\karab\Downloads\makeup_data/makeup_data.json')

# Now you can print the columns of the dataframe
print(makeup_df.columns)

# Additional comments about the dataset
# id: Unique product ID
# brand: Brand name
# name: Product name
# price_sign: Currency symbol (e.g., $, €, etc.)

# Converting the JSON data to a pandas DataFrame for easier manipulation
makeup_df = pd.json_normalize(makeup_data)

# Displaying the column names to understand what needs cleaning and filtering
makeup_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 5
#       1 #Please use code cells to code in and do not forget to comment your code.
#       2 # The dataset contains the following columns:
#       3
#       4 # Example of printing the columns of the dataframe
# ----> 5 print(makeup_df.columns)
#       7 # id: Unique product ID
#       8 # brand: Brand name
#       9 # name: Product name
#      10 price_sign = "Currency symbol (e.g., $, €, etc.)"
#
# NameError: name 'makeup_df' is not defined

# %% [markdown]
# ---
# <a href=#five></a>
# ## **Exploratory Data Analysis (EDA)**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Explore and visualize the data to uncover patterns, trends, and relationships.
# * **Details:** Use statistics and visualizations to explore the data. This may include histograms, box plots, scatter plots, and correlation matrices. Discuss any significant findings.
# ---

# %%
#Please use code cells to code in and do not forget to comment your code.
# !pip install pandas matplotlib seaborn
import pandas as pd
import zipfile

# Path to the ZIP file
zip_file_path = r'C:\Users\karab\Downloads\makeup_data.json.zip'

# Extract the ZIP file to a temporary directory
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(r'C:\Users\karab\Downloads\makeup_data')

# Load the JSON file into a DataFrame
makeup_df = pd.read_json(r'C:\Users\karab\Downloads\makeup_data/makeup_data.json')

# Get the basic statistics of the numerical columns
print(makeup_df.describe())

# Count how many products each brand has
brand_counts = makeup_df['brand'].value_counts()
print(brand_counts)

# Get the basic statistics of the numerical columns
makeup_df.describe()

# Count how many products each brand has
brand_counts = makeup_df['brand'].value_counts()
print(brand_counts)
# Visualizing Price Distribution
plt.figure(figsize=(10, 6))
sns.histplot(makeup_df['price'], bins=20, kde=True)
plt.title('Distribution of Product Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# Convert 'price' to numeric values, forcing errors to NaN
makeup_df['price'] = pd.to_numeric(makeup_df['price'], errors='coerce')

# Plot a histogram of product prices
plt.figure(figsize=(10, 6))
sns.histplot(makeup_df['price'], bins=20, kde=True)
plt.title('Distribution of Product Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# Create a boxplot for price distribution by product type
plt.figure(figsize=(12, 8))
sns.boxplot(x='product_type', y='price', data=makeup_df)
plt.xticks(rotation=90)
plt.title('Price Distribution by Product Type')
plt.show()



# Correlation matrix between numerical variables
corr_matrix = makeup_df[['price', 'rating']].corr()

# Heatmap of the correlation matrix
plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Price and Rating')
plt.show()

# Scatter plot of price vs rating
plt.figure(figsize=(10, 6))
sns.scatterplot(x='price', y='rating', data=makeup_df)
plt.title('Price vs. Rating')
plt.xlabel('Price')
plt.ylabel('Rating')
plt.show()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#                 id       price      rating
# count   931.000000  917.000000  340.000000
# mean    531.163265   16.508593    4.319118
# std     311.054915   11.028035    0.675849
# min       1.000000    0.000000    1.500000
# 25%     263.000000    8.990000    4.000000
# 50%     518.000000   13.990000    4.500000
# 75%     814.500000   22.000000    5.000000
# max    1048.000000   77.000000    5.000000
# brand
# nyx                         164
# clinique                     93
# dior                         74
# maybelline                   54
# covergirl                    54
# smashbox                     46
# l'oreal                      46
# physicians formula           43
# benefit                      41
# revlon                       29
# e.l.f.                       27
# cargo cosmetics              20
# pure anada                   16
# marcelle                     15
# ...

# %% [markdown]
# ---
# <a href=#six></a>
# ## **Modeling**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Develop and train predictive or statistical models.
# * **Details:** Describe the choice of models, feature selection and engineering processes, and show how the models are trained. Include code for setting up the models and explanations of the model parameters.
# ---

# %%
#Please use code cells to code in and do not forget to comment your code.

# %% [markdown]
# ---
# <a href=#seven></a>
# ## **Evaluation and Validation**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Evaluate and validate the effectiveness and accuracy of the models.
# * **Details:** Present metrics used to evaluate the models, such as accuracy, precision, recall, F1-score, etc. Discuss validation techniques employed, such as cross-validation or train/test split.
# ---

# %%
#Please use code cells to code in and do not forget to comment your code.

# %% [markdown]
# ---
# <a href=#eight></a>
# ## **Final Model**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Present the final model and its performance.
# * **Details:** Highlight the best-performing model and discuss its configuration, performance, and why it was chosen over others.
# ---

# %%
#Please use code cells to code in and do not forget to comment your code.

# %% [markdown]
# ---
# <a href=#nine></a>
# ## **Conclusion and Future Work**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Summarize the findings and discuss future directions.
# * **Details:** Conclude with a summary of the results, insights gained, limitations of the study, and suggestions for future projects or improvements in methodology or data collection.
# ---

# %%
#Please use code cells to code in and do not forget to comment your code.

# %% [markdown]
# ---
# <a href=#ten></a>
# ## **References**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Provide citations and sources of external content.
# * **Details:** List all the references and sources consulted during the project, including data sources, research papers, and documentation for tools and libraries used.
# ---

# %%
#Please use code cells to code in and do not forget to comment your code.

# %% [markdown]
# ## Additional Sections to Consider
#
# * ### Appendix:
# For any additional code, detailed tables, or extended data visualizations that are supplementary to the main content.
#
# * ### Contributors:
# Karabo Mathibela.
